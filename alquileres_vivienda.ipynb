# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuelcb08/Actividades_Nuevastecnologias/blob/main/alquileres_vivienda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos_viviendas = pd.read_csv("/content/drive/MyDrive/Alquileres_viviendas.csv", sep = ";")

# %%
datos_viviendas.head(65)
# Out:
#     Unnamed: 0          Tipo                Distrito  Cuartos  Vacantes  \
# 0            0          Casa              Lurigancho        2         0
# 1            1  Departamento              Pachacámac        1         0
# 2            2  Departamento                     Ate        1         0
# 3            3  Departamento                Barranco        3         1
# 4            4  Departamento                   Comas        2         0
# ..         ...           ...                     ...      ...       ...
# 60          60  Departamento  San Juan de Lurigancho        3         4
# 61          61  Departamento              Chaclacayo        2         1
# 62          62  Departamento                     Ate        3         2
# 63          63  Departamento             Santa Anita        3         1
# 64          64  Departamento           Punta Hermosa        2         1
#
#     Suites  Area   Valor  Mantenimiento  Impuesto
# 0        1   100  7000.0            NaN       NaN
# ...

# %%
sel_departamentos = datos_viviendas["Tipo"]== "Departamento"
cant_dpto_otras = datos_viviendas[~sel_departamentos].shape[0]
cant_dpto_otras
# Out:
# 967

# %%
sel_casa_hab_cochera = (datos_viviendas["Tipo"] == "Casa") | (datos_viviendas["Tipo"] == "Departamento" ) | (datos_viviendas["Tipo"] == "Cochera")
cant_casa_hab_cochera = datos_viviendas[sel_casa_hab_cochera].shape[0]
cant_casa_hab_cochera
# Out:
# 20499

# %%
sel_area = (datos_viviendas['Area']>=60)& (datos_viviendas['Area']<=100)
sel_area
cantidad_viv_area = datos_viviendas[sel_area].shape[0]
cantidad_viv_area
# Out:
# 8510

# %%
sel_hab_precio = (datos_viviendas['Cuartos']>=4) &(datos_viviendas['Valor']<= 2000)
cant_hab_precio = datos_viviendas[sel_hab_precio].shape[0]
cant_hab_precio
# Out:
# 55

# %%
print("Se encontraron los siguientes resultados: ")
print(f"El numero de departamentos es de {cant_dpto}")
print(f"el numero de viviendas restantes es de {cant_dpto_otras}")
print(f"El numero de viviendas de tipo casa, departamento es {cant_casa_hab_cochera}")
print(f"la cantidad con un area entre 60 y 100 metros cuadrados es de {cantidad_viv_area}")
# Out:
# Se encontraron los siguientes resultados:
# El numero de departamentos es de 967
# el numero de viviendas restantes es de 967
# El numero de viviendas de tipo casa, departamento es 20499
# la cantidad con un area entre 60 y 100 metros cuadrados es de8510

# %%
datos_viviendas.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0          Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 0               0          Casa   Lurigancho        2         0       1   100
# 1               1  Departamento   Pachacámac        1         0       0    15
# 2               2  Departamento          Ate        1         0       0    48
# 3               3  Departamento     Barranco        3         1       0    70
# 4               4  Departamento        Comas        2         0       0    50
# ...           ...           ...          ...      ...       ...     ...   ...
# 20494       20494  Departamento          Ate        2         0       0    52
# 20495       20495  Departamento  Santa Anita        2         0       0    70
# 20496       20496  Departamento        Lince        3         1       2    78
# 20497       20497  Departamento        Rímac        2         1       0    48
# 20498       20498  Departamento        Rímac        2         0       0    70
#
# ...

# %%
datos_viviendas[datos_viviendas['Valor'].isnull()]
# Out:
#       Unnamed: 0          Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 50            50  Departamento          Ate        2         1       1    70
# 1355        1355  Departamento  San Bartolo        2         0       0    75
# 1529        1529          Casa        Lince        3         4       3   363
# 1831        1831  Departamento   Chorrillos        2         0       0    95
# 1853        1853  Departamento    San Borja        2         0       0    72
# 4498        4498          Casa        Lince        3         2       1   100
# 7794        7794  Departamento  San Bartolo        2         0       1    75
# 8146        8146  Departamento     La Punta        3         0       1   135
# 8326        8326  Departamento     La Perla        3         1       1   105
#
#       Valor  Mantenimiento  Impuesto
# 50      NaN          970.0      68.0
# 1355    NaN          878.0       NaN
# 1529    NaN            NaN       NaN
# 1831    NaN         1010.0     170.0
# ...

# %%
viviendas_nan = datos_viviendas.shape[0]
datos_viviendas.dropna(subset= ['Valor'],inplace= True)
viviendas_nan_b = datos_viviendas.shape[0]
viviendas_nan - viviendas_nan_b
# Out:
# 9

# %%
datos_viviendas[datos_viviendas['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Tipo, Distrito, Cuartos, Vacantes, Suites, Area, Valor, Mantenimiento, Impuesto]
# Index: []

# %%
datos_viviendas[datos_viviendas['Mantenimiento'].isnull()].shape[0]
# Out:
# 1500

# %%
sel= (datos_viviendas['Tipo'] == 'Departamento')&(datos_viviendas['Mantenimiento'].isnull())

# %%
sel_A = datos_viviendas.shape[0]
datos_viviendas = datos_viviendas[~sel]
sel_B = datos_viviendas[0]
sel_A - sel_B
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
sel.shape[0]
# Out:
# 19745

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-504dc0a05c0e> in <cell line: 1>()
# ----> 1 datos_viviendas = datos_viviendas[~self]
#       2 datos_viviendas
#
# NameError: name 'self' is not defined
